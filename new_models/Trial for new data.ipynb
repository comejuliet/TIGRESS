# %%
import sys
import os
import os.path as osp
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize, LogNorm

sys.path.insert(0,'..')
#import pyathena as pa

# %%
import pandas as pd

from pyathena import LoadSim
from pyathena.util.units import Units

from pyathena.tigress_ncr.hst import Hst
from pyathena.tigress_ncr.load_sim_tigress_ncr import LoadSimTIGRESSNCR

# %%
s = LoadSimTIGRESSNCR('/data/comejuliet/NCRSP/R8_8pc_NCRSP.full.y2.xy1024.eps0.np768.has/')
# Out:
# LoadSimTIGRESSNCR-WARNING: Vtk file size is not unique.
# LoadSimTIGRESSNCR-WARNING: zprof files not found in /data/comejuliet/NCRSP/R8_8pc_NCRSP.full.y2.xy1024.eps0.np768.has.
# LoadSimTIGRESSNCR-WARNING: rst files not found in /data/comejuliet/NCRSP/R8_8pc_NCRSP.full.y2.xy1024.eps0.np768.has.
# /home/comejuliet/miniconda3/envs/pyathena/lib/python3.10/site-packages/dateutil/parser/_parser.py:1207: UnknownTimezoneWarning: tzname PDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "

# %%
vtk = s.load_vtk(s.nums[-1])
vtk.domain
# Out:
# {'all_grid_equal': True,
#  'ngrid': 768,
#  'le': array([-1024., -2048., -3072.], dtype=float32),
#  're': array([1024., 2048., 3072.], dtype=float32),
#  'dx': array([8., 8., 8.], dtype=float32),
#  'Lx': array([2048., 4096., 6144.], dtype=float32),
#  'center': array([0., 0., 0.], dtype=float32),
#  'Nx': array([256, 512, 768]),
#  'ndim': 3,
#  'time': 480.0002}

# %%
h = s.read_hst()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 h = s.read_hst()
#
# File ~/pyathena/pyathena/load_sim.py:915, in LoadSim.Decorators.check_pickle_hst.<locals>.wrapper(cls, *args, **kwargs)
#     912 cls.logger.info('[read_hst]: Reading original hst file.')
#     913 # If we are here, force_override is True or history file is updated.
#     914 # Call read_hst function
# --> 915 hst = read_hst(cls, *args, **kwargs)
#     916 try:
#     917     hst.to_pickle(fpkl)
#
# File ~/pyathena/pyathena/tigress_ncr/hst.py:92, in Hst.read_hst(self, savdir, force_override)
#      90 if self.test_phase_sep_hst():
#      91     self.logger.info("[read_hst]: Reading phase separated history files...")
# ---> 92     hph = self.read_hst_phase_all()
#      93     hw = self.read_hst_phase(iph=0)
#      94     h['massflux_lbd_d'] = hw['Fzm_lower']*u.mass_flux
#
# ...

# %%
s.par['problem']

# %%
plt.figure(figsize=(6,6))
plt.plot(h['time'],h['sfr100'], label = "age < 100 Myr")
plt.plot(h['time'],h['sfr40'], label = "age < 40 Myr")
plt.plot(h['time'],h['sfr10'], label = "age < 10 Myr")
plt.yscale('log')
plt.xticks(fontsize= 18)
plt.ylim(10**-4,10**-1)
plt.xlabel('t (Myr)', fontsize = 18)
plt.legend(fontsize= 15)

# %%
vtk = s.load_vtk(s.nums[-1])
vtk.domain
# Out:
# {'all_grid_equal': True,
#  'ngrid': 768,
#  'le': array([-1024., -1024., -3072.], dtype=float32),
#  're': array([1024., 1024., 3072.], dtype=float32),
#  'dx': array([8., 8., 8.], dtype=float32),
#  'Lx': array([2048., 2048., 6144.], dtype=float32),
#  'center': array([0., 0., 0.], dtype=float32),
#  'Nx': array([256, 256, 768]),
#  'ndim': 3,
#  'time': 470.0009}
